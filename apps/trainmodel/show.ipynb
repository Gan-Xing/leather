# %%
import matplotlib.pyplot as plt

# Data
epochs = range(1, 21)
train_losses = [2.2634947697321572, 1.3237197399139404, 0.7856371601422628, 0.5529379745324453, 0.4283146858215332, 0.28864413499832153, 0.26284560064474743, 0.1803384522596995, 0.15725369254748026, 0.11443840463956197, 0.1226465826233228, 0.09754279752572377, 0.09171193838119507, 0.09095816562573115, 0.06686938926577568, 0.06153717885414759, 0.05277806892991066, 0.050034746527671814, 0.045771547903617225, 0.04862408712506294]
train_accuracies = [0.26302084, 0.8229167, 0.9817708, 0.9921875, 0.9947917, 0.9947917, 0.9895833, 0.9973958, 1.0, 1.0, 0.9973958, 1.0, 0.9973958, 0.9947917, 0.9973958, 0.9973958, 1.0, 1.0, 1.0, 1.0]

test_losses = [1.9332375923792522, 1.5878223180770874, 1.355455716451009, 1.1982381741205852, 1.077837586402893, 1.0004706978797913, 0.9359596769014994, 0.8853792945543925, 0.8424258232116699, 0.8110859791437784, 0.7798800667126974, 0.7535976568857828, 0.7295694748560587, 0.7079118490219116, 0.6898688077926636, 0.6734884182612101, 0.6596519152323405, 0.6466436187426249, 0.6350985169410706, 0.6240042448043823]
test_accuracies = [0.4947916666666667, 0.78125, 0.890625, 0.9166666666666666, 0.9322916666666666, 0.9375, 0.9453125, 0.953125, 0.9557291666666666, 0.9583333333333334, 0.9557291666666666, 0.9557291666666666, 0.9557291666666666, 0.9557291666666666, 0.953125, 0.9583333333333334, 0.9583333333333334, 0.9557291666666666, 0.9583333333333334, 0.9557291666666666]

# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Loss Plot
ax1.plot(epochs, train_losses, 'r-o', label='Train Loss')
ax1.plot(epochs, test_losses, 'r--o', label='Test Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss', color='red')
ax1.tick_params(axis='y', labelcolor='red')

# Create a second y-axis for the accuracies
ax2 = ax1.twinx()  
ax2.plot(epochs, train_accuracies, 'b-s', label='Train Accuracy')
ax2.plot(epochs, test_accuracies, 'b--s', label='Test Accuracy')
ax2.set_ylabel('Accuracy', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# Title and legends
plt.title('Training and Testing Metrics Per Epoch')
fig.tight_layout()  # To adjust subplot parameters to give specified padding
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.show()
